# %%
"""
Created on Sun Oct 18 2020

@author: Sarah.Medina
"""

"""
Docstring:

    A) Introduction:
    Today we are going to play a game called Baking with celebrities. This game consists of four
    rounds. As the player your actions help determine the dish you make and if you make it through each round. 
    As you pass through each round, your choices determine if you are able to make it to the end and win 
    the game. Your choice has the power to determine your luck!
    
    Round 1: Choose what recipe will be made
    Round 2: Determine your next baking action
    Round 3: Determine your next baking action
    Round 4: Keep of trade your dish
    
    B) Known Bugs and/ or Errors:
    None.

"""
#Adding imports
from sys import exit
from random import randint

#writing a game start function
#defining global
def game_start():
    global city_from
    global covid
    global contestant_name
    global country
    global celebrity
    global professor
    global sweets
    global junk_food
   
    

#input/ prompts to create dynamic code   
    contestant_name = input(prompt = f"""\nHello and welcome to Food Networks newest show, Baking with celebrities! I'm Gordon Ramsay, 
your host for today! And what is our lucky contestants name?\n""").capitalize()
    #start of dynamic code
    print(f"""
Welcome \033[92m{contestant_name}\033[0m!\U0001F601
""")
    #using this input to space out the game 
    input('<Press enter to continue>\n')
    print(f"""\nLet's get to know you a little bit better, \033[92m{contestant_name}\033[0m\n
""")
    #additional input prompts
    city_from  = input(prompt = f"Name a city:\t").upper()
    
    covid =input(prompt = f"Name an everyday good that was hard to find during covid (ex: tp, hand sanny...):\t").upper()
    
    sweets = input(prompt = f"What is your favorite baked sweet?\t").capitalize()
    
    country = input(prompt = f"Where are you from?\t").upper()
                    
    celebrity = input(prompt = f"Who is your favorite celebrity?\t").capitalize()
    
    professor = input(prompt = f"What is our professors name?\t").capitalize()
    
    junk_food = input(prompt = f"Name store bought sweet (ex: twinkies, oreos...):\t").casefold()
#using dynamic code to print the intro    
    print(f"""\n 
Joining me on stage today is \033[92m{contestant_name}\033[0m, all the way from \033[92m{country}\033[0m. Today they will face off in \033[92m{city_from}\033[0m 
with the one and only, \033[92m{celebrity}\033[0m to compete for the title of best baker and walk away with $10,000! 
I get the pleasure of personally screaming at the loser as they run away crying!
""")
    #introduction to judge 
    input('<Press enter to continue>\n')
    print(f"""
And who could our mystery judge be who will taste your desserts and name the new reigning champion????? 
Drum roll please!!! 
""")
    input('<Press enter to continue>')
    print(f"""
\033[92m{professor}\033[0m!! Thank you for being our judge today\U0001F601!
""")
    
    input('<Press enter to continue>\n')
    #additional dynamic code explaining the game to the contestant
    print(f""" 
Today there will be one round where \033[92m{contestant_name}\033[0m  and \033[92m{celebrity}\033[0m will face off in a category of our choosing! 
You will have one hour to show off your best baking skills and win over our judge, \033[92m{professor}\033[0m!\n""")

    input('<Press enter to continue>\n')
    
    print(f"""Let's get this party STARTED\U0001F973! We'll be back after this short commercial break sponsored by \033[92m{covid}\033[0m lovers!
    """)
    
    input('<Press enter to continue>\n')
    #sending user to round one
    round_1()

#start of round 1
def round_1():
    print("\nI'm Gordon Ramsay. Welcome back to Baking with Celebrities!")
    input('<Press enter to continue>\n')
    #using dynamic code to explain round one 
    print(f"""
Now, \033[92m{contestant_name}\033[0m, as you're not a celebrity and all and \033[92m{celebrity}\033[0m is my favorite, you get three chances to guess 
our category for today. Your choices are cookies, cupcakes, grandmas specialties, or cakes. Guess wrong and 
we'll replace you with someone better.
""")
    input('<Press enter to continue>\n')
    
    
#starting a while loop for dessert choice
#setting the number of attempts
    chances = 3
    #exiting the loop after 3 attempts
    while chances > 0:
        #dessert choice is random through use of randint
        choices = randint(0,3)
        print(f"""
\033[92m{contestant_name}\033[0m, what will you guess?
        A.) Cookies\U0001F36A
        B.) Cupcakes\U0001F9C1
        C.) Grandma's specialties\U0001F475
        D.) Cakes\U0001F382
""")
        #conditional within a loop for option A
        dessert = input(">").casefold()
        if "a" in dessert or "cookie" in dessert:
            #printing the statement if the random choice equals the first option
            if choices == 0:
                #dynamic code to present dessert choice if correct choice is "A"
                print(f"""
You know what, since I'm the host, I'm going to choose! Today we are making \033[92m{sweets}\033[0m!!
""")
                input('<Press enter to continue>\n')
                #user taken to next round
                round_2()
                break
            
            else:
                print(f"""
Oh darn! Sorry \033[92m{contestant_name}\033[0m, that's incorrect.)
""")
                
                #user has one less turn if the choice is wrong
                chances -=1
            
            
        #conditional for loop within option B
        elif "b" in dessert or "cupcake" in dessert:
            if choices == 1:
                #print statement if choice "B" is correct
                print(f"""
You know what, since I'm the host, I'm going to choose! Today we are making \033[92m{sweets}\033[0m!!

""")
                input('<Press enter to continue>\n')
                #user taken to next round
                round_2()
                break
          
            else:
                print(f"""
Oh darn! Sorry \033[92m{contestant_name}\033[0m, that's incorrect.)

""")
                #user has one less turn if the choice is wrong
                chances -= 1
                
            
        #conditional for loop within option C        
        elif "c" in dessert or "grandma" in dessert:
            if choices == 2 :
                 #print statement if choice  "C" is correct
                print(f"""
You know what, since I'm the host, I'm going to choose! Today we are making \033[92m{sweets}\033[0m!!

""")
                
                input('<Press enter to continue>\n')
                #user taken to next round
                round_2()
                break
      
            else:
                print(f"""
Oh darn! Sorry \033[92m{contestant_name}\033[0m, that's incorrect.)
""")
                #user has one less turn if the choice is wrong
                chances -= 1
            
               
     #conditional for loop within option D
        elif "d" in dessert or "cake" in dessert:
            if choices == 3 :
                #print statement if choice "D" is correct
                print(f"""
You know what, since I'm the host, I'm going to choose! Today we are making \033[92m{sweets}\033[0m!!
""")
                input('<Press enter to continue>\n')
                #user taken to next round
                round_2()
                break
      
            else:
                print(f"""
Oh darn! Sorry \033[92m{contestant_name}\033[0m, that's incorrect. Try again.)

""")
                #user has one less turn if the choice is wrong
                chances -= 1
                
        
    #fail function so player has option to exit or play again
    fail()

#starting round 2
def round_2():
    print(f"""Congratulations\U0001F389 \033[92m{contestant_name}\033[0m and \033[92m{celebrity}\033[0m! Today you will be making \033[92m{sweets}\033[0m! 
I hope you're as excited as \033[92m{professor}\033[0m and I am!
    """)
    input('<Press enter to continue>\n')
    print(f"""And the timer starts in... 

""")
    timer = 3
    #looping while timer is greater than zero
    while timer >= 1:
        print(timer)
    #calling out the timer
        timer -=1   
        input('<Press enter to continue>')
    #go!
    print("Go!!!\n")
            
      
            

    print(f"""Okay, \033[92m{contestant_name}\033[0m, now that you know you are going to make \033[92m{sweets}\033[0m, and you've grabbed
all your ingredients, what are you going to do first?
""")
    guess=input(f"""\n
    A). Sift the flour 
    B). Whisk your eggs
    C). Cry
    D). Admire your competitor\U0001F60D, \033[92m{celebrity}\033[0m from afar\n>
""").lower()
 

    #Conditional...user option is always right
    #conditional statement to prevent bugs in first option
    if "a" in guess or "sift" in guess or "flour" in guess:
        print(f"""Great job, \033[92m{contestant_name}\033[0m! Let's keep going!""")
        input("<Press enter to continue>\n")
        
        #push user to round 3
        round_3()
    #conditional to prevent bugs in second option
    elif "b" in guess or "whisk" in guess or "eggs" in guess:
        print(f"""Great job, \033[92m{contestant_name}\033[0m! Let's keep going!""")
        input("<Press enter to continue>\n")
        #push user to round 3
        round_3()
    #conditional to prevent bugs if third option is chosen
    elif "c" in guess or "cry" in guess:
        print(f"""Great job, \033[92m{contestant_name}\033[0m! Let's keep going!""")
        input("<Press enter to continue>\n")
        #push user to round 3
        round_3()
    #conditional to prevent bugs if fourth option is chosen
    elif "d" in guess or "admire" in guess or "judge" in guess:
        print(f"""Great job, \033[92m{contestant_name}\033[0m! Let's keep going!""")
        input("<Press enter to continue>\n")
        #push user to round 3
        round_3()
    else:
        print(f""" \033[92m{contestant_name}\033[0m, you were supposed to pick a letter. Try again.
            """)
    

   #fail option to boot out user or ask them to play again
    fail()
    
#starting round 3                        
def round_3(): 
    #dynamic function to start round 3
    print(f"""
It looks like we are half way done on time. Let's go take a look at how \033[92m{contestant_name}\033[0m is
dealing with the pressure!
""")
    input('<Press enter to continue>\n')
    #dynamic function...hurry up
    print(f"""
Now \033[92m{contestant_name}\033[0m, I see that you still havent put your \033[92m{sweets}\033[0m in the oven...
I heard that \033[92m{professor}\033[0m doesn't like undercooked desssert, so I'd hurry up if I were you!
""")
    input('<Press enter to continue>\n')

#creating a loop for round 3    
    chances = 2 
    
    #While loop for action_2
    while chances > 0:
        action_2 = randint(0,2)
        print(f"""
\033[92m{celebrity}\033[0m already has theirs in the oven! What are you going to do, \033[92m{contestant_name}\033[0m?
    A)Oven time!
    B)Add your special ingredient quick!!
    C)Ask Gordon for help (I won't tell if you wont!)
""")
        
        decision_2 = input("> ").casefold()
        #conditional within a loop for bug prevention
            #for bug prevention
        
        #cond within a loop when answer is first choice/ "A"
        if "a" in decision_2 or "oven" in decision_2:
            if action_2 == 0:
                print(f"""
\033[92m{contestant_name}\033[0m, you really are a pro. I'm surprised you're still here to be honest! Anyways, time is 
running out. Plate your \033[92m{sweets}\033[0m and let's see if \033[92m{professor}\033[0m actually eats it!""")
                input('<Press enter to continue>\n')
                
                #if randint equals user input, user goes to round 4
                round_4()
                break
            else: 
                print(f"""
For the first time ever in the history of Baking with Celebrities, \033[92m{contestant_name}\033[0m 
has successfully lit \033[92m{celebrity}\033[0m's hair on fire\U0001F525....Although \033[92m{celebrity}\033[0m is now bald, the show must 
go on! Choose again.
""")
                #One less chance if  "A" does not equal randint
                chances -=1
        
        #cond within a loop when answer is second choice/ "B"
        elif "b" in decision_2 or "add" in decision_2 or "special ingredient" in decision_2:
            if action_2 == 1:
                print(f"""
\033[92m{contestant_name}\033[0m, you really are a pro. I'm surprised you're still here to be honest! Anyways, time is 
running out. Plate your \033[92m{sweets}\033[0m and let's see if \033[92m{professor}\033[0m actually eats it!""")
                input('<Press enter to continue>\n')
                
                #if randint equals user input, user goes to round 4
                round_4()
                break
            else: 
                print(f"""
For the first time ever in the history of Baking with Celebrities, \033[92m{contestant_name}\033[0m 
has successfully lit \033[92m{celebrity}\033[0m's hair on fire\U0001F525....Although \033[92m{celebrity}\033[0m is now bald, the show must 
go on! Choose again.
""")
                #One less chance if "B" does not equal randint
                chances -=1
            
        #cond within a loop when answer is third choice/ "C"
        elif "c" in decision_2 or "ask" in decision_2 or "gordon" or "help" in decision_2:
            if action_2 == 2:
                print(f"""
\033[92m{contestant_name}\033[0m, you really are a pro. I'm surprised you're still here to be honest! Anyways, time is 
running out. Plate your \033[92m{sweets}\033[0m and let's see if \033[92m{professor}\033[0m actually eats it!""")
                input('<Press enter to continue>\n')
                #if randint equals user input, user goes to round 4
                round_4()
                break
            else: 
                print(f"""
For the first time ever in the history of Baking with Celebrities, \033[92m{contestant_name} 
has successfully lit \033[92m{celebrity}\033[0m's hair on fire\U0001F525....Although \033[92m{celebrity}\033[0m is now bald, the show must 
go on! Choose again.
""")
                
                #One less chance if "C" does not equal randint
                chances -=1
    #fail function to boot out user or ask them to play again
    fail()


#starting round 4    
def round_4():
    #dynamic code to explain round 4
    print(f"""
Contestants \033[92m{contestant_name}\033[0m and \033[92m{celebrity}\033[0m have now plated their \033[92m{sweets}\033[0m and are anxiously waiting on 
\033[92m{professor}\033[0m to name the newest winner on Baking with celebrities!! \033[92m{contestant_name}\033[0m, you have one 
more choice to make...
""")
    input('<Press enter to continue>\n')
    
    #dynamic code for one last challenge
    print(f"""
\033[92m{contestant_name}\033[0m, you have the choice of keeping the \033[92m{sweets}\033[0m you made or trading your dish for what is 
behind this door, which may have been \033[92m{sweets}\033[0m, made yours truly or a dessert I picked up from 
Walmart on the way over. Choice is yours. Just remember, the show is live...
""")
    
    input('<Press enter to continue>\n')
    
    print(f"""
\033[92m{contestant_name}\033[0m, what's your pick?
    A.) Keep my dish
    B.) Trade it
    
""")
    #using a conditional for pick's A or B
    pick = input('> ').casefold()
    dish = randint(0,1)
    
    #conditional if user chooses first pick
    #cond within a cond to prevent bugs when user chooses first pick
    if "a" in pick or "keep" in pick: 
        if dish == 0:
            print(f"""
Wow, \033[92m{contestant_name}\033[0m you won\U0001F389!!! Our judge, \033[92m{professor}\033[0m loved your \033[92m{sweets}\033[0m! You can now say that 
you beat my favorite celebrity \033[92m{celebrity}\033[0m on live television! Congratulations! Here's your $10,000. 
BYE!!!!
""")
            input('<Press any key to exit>\n')
            #if first choice != randint, player is booted out of game
            exit(0)
        
        else:
            print(f"""
\033[92m{contestant_name}\033[0m, it seems as though you left your \033[92m{sweets}\033[0m in the oven for way too long. 
\033[92m{professor}\033[0m loved \033[92m{celebrity}\033[0m and his perfectly delicous \033[92m{sweets}\033[0m. Trading your \033[92m{sweets}\033[0m would have been in your best interest... 
""")
    
    #conditional if user chooses second pick
    #cond within a cond to prevent bugs when user chooses second pick
    if "b" in pick or "trade" in pick: 
        if dish == 1:
            print(f"""
Wow, \033[92m{contestant_name}\033[0m you won\U0001F389!!! Our judge, \033[92m{professor}\033[0m loved your \033[92m{sweets}\033[0m! Good news is you pocketed $10,000.
Bad news is all of \033[92m{country}\033[0m knows you traded your dish. Well at least you met \033[92m{celebrity}\033[0m. Congratulations! 
BYE!!!!
""")
            input('<Press any key to exit>\n')
            #if second choice != randint, player is booted out of game 
            exit(0)
        
        else:
            print(f"""
\033[92m{contestant_name}\033[0m, you should be ashamed. I can't believe you served \033[92m{professor}\033[0m some \033[92m{junk_food}\033[0m from Walmart
of all places. Of course as I knew all along, \033[92m{celebrity}\033[0m would make better \033[92m{sweets}\033[0m anyways.
""")
            #fail function to boot player out game or play again 
            fail()
            
#creating a fail function for each round
def fail():
    #using dynamic code if user is looped out 
    print(f"""
Bummer! I'm sorry \033[92m{contestant_name}\033[0m, you lost and of course that means my favorite person \033[92m{celebrity}\033[0m wins! 

""")
        
    print(f"Ok, \033[92m{contestant_name}\033[0m, I'll try to be nicer. Would you like to compete again?(Yes/No)")
    #conditional statement for replay
    replay = input("> ")
    replay = replay.lower()
    
    #Yes function to replay/ get user back to round 1
    if 'y' in replay or 'yes' in replay:
            #player to round 1 
            round_1()
    #exit the game if player does not choose yes    
    else:
        print(f"See ya later \033[92m{contestant_name}\033[0m!")
        exit(0)

#game start function to restart game
game_start()
# Out:
# Hello and welcome to Food Networks newest show, Baking with celebrities! I'm Gordon Ramsay,
# your host for today! And what is our lucky contestants name?
# sarah
#
# Welcome Sarah!😁
#
# <Press enter to continue>
#
#
# Let's get to know you a little bit better, Sarah
#
#
# Name a city:
# Name an everyday good that was hard to find during covid (ex: tp, hand sanny...):	tp
# What is your favorite baked sweet?	cookies
# Where are you from?	sd
# Who is your favorite celebrity?	bob
# What is our professors name?	chase
# Name store bought sweet (ex: twinkies, oreos...):	oreos
#
#
# Joining me on stage today is Sarah, all the way from SD. Today they will face off in
# with the one and only, Bob to compete for the title of best baker and walk away with $10,000!
# I get the pleasure of personally screaming at the loser as they run away crying!
#
# <Press enter to continue>
#
#
# And who could our mystery judge be who will taste your desserts and name the new reigning champion?????
# ...
